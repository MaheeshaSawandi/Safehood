# %% [markdown]
# <a href="https://colab.research.google.com/github/MaheeshaSawandi/Safehood/blob/Prediction-Model/XG3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

from xgboost import XGBClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    roc_auc_score
)

import joblib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel(
    "/content/drive/MyDrive/SafeHood_ML/Dataset/processed_dataset.xlsx"
)

df.head()
# Out:
#      Location  Year  Month  Crime_Count  Average_Severity  Maximum_Severity  \
# 0  Abhayapura  2016      1           26          6.846154                10
# 1  Abhayapura  2016      2           33          6.606061                10
# 2  Abhayapura  2016      3           19          7.157895                10
# 3  Abhayapura  2016      4           21          7.000000                10
# 4  Abhayapura  2016      5           15          6.000000                10
#
#    Next_Month_Crime Future_Risk
# 0              33.0        High
# 1              19.0      Medium
# 2              21.0      Medium
# 3              15.0      Medium
# 4              28.0      Medium

# %%
print(df.shape)

df.info()
# Out:
# (5638, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5638 entries, 0 to 5637
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          5638 non-null   object
#  1   Year              5638 non-null   int64
#  2   Month             5638 non-null   int64
#  3   Crime_Count       5638 non-null   int64
#  4   Average_Severity  5638 non-null   float64
#  5   Maximum_Severity  5638 non-null   int64
#  6   Next_Month_Crime  5570 non-null   float64
#  7   Future_Risk       5638 non-null   object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 352.5+ KB

# %%
df.isnull().sum()
# Out:
# Location             0
# Year                 0
# Month                0
# Crime_Count          0
# Average_Severity     0
# Maximum_Severity     0
# Next_Month_Crime    68
# Future_Risk          0
# dtype: int64

# %%
df = df.dropna()

# %%
df["Future_Risk"].value_counts()
# Out:
# Future_Risk
# Medium    2737
# Low       2557
# High       276
# Name: count, dtype: int64

# %%
encoder = LabelEncoder()

df["Location_Code"] = encoder.fit_transform(
    df["Location"]
)

# %%
features = [

    "Location_Code",

    "Year",

    "Month",

    "Crime_Count",

    "Average_Severity",

    "Maximum_Severity"

]

# %%
X = df[features]

y = df["Future_Risk"]

# %%
target_encoder = LabelEncoder()

y_encoded = target_encoder.fit_transform(y)

# %%
target_encoder.classes_
# Out:
# array(['High', 'Low', 'Medium'], dtype=object)

# %%
train = df[df["Year"] <= 2023]

test = df[df["Year"] > 2023]

# %%
X_train = train[features]

X_test = test[features]

# %%
y_train = target_encoder.transform(
    train["Future_Risk"]
)


y_test = target_encoder.transform(
    test["Future_Risk"]
)

# %%
print(X_train.shape)

print(X_test.shape)
# Out:
# (4539, 6)
# (1031, 6)

# %%
xgb_model = XGBClassifier(

    n_estimators=150,

    learning_rate=0.2,

    max_depth=2,

    random_state=42,

    objective="multi:softmax",

    num_class=3

)

# %%
xgb_model.fit(

    X_train,

    y_train

)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=150,
#               n_jobs=None, num_class=3, ...)

# %%
xgb_prediction = xgb_model.predict(

    X_test

)

# %%
accuracy = accuracy_score(

    y_test,

    xgb_prediction

)

print(
"Accuracy:",
accuracy
)
# Out:
# Accuracy: 0.9437439379243453

# %%
precision = precision_score(

    y_test,

    xgb_prediction,

    average="weighted"

)

print(
"Precision:",
precision
)
# Out:
# Precision: 0.9341680938479416

# %%
recall = recall_score(

    y_test,

    xgb_prediction,

    average="weighted"

)

print(
"Recall:",
recall
)
# Out:
# Recall: 0.9437439379243453

# %%
f1 = f1_score(

    y_test,

    xgb_prediction,

    average="weighted"

)

print(
"F1 Score:",
f1
)
# Out:
# F1 Score: 0.9272951614332069

# %%
print(
classification_report(

    y_test,

    xgb_prediction,

    target_names=target_encoder.classes_

)
)
# Out:
#               precision    recall  f1-score   support
#
#         High       0.70      0.12      0.21        56
#          Low       0.99      1.00      0.99       445
#       Medium       0.91      0.99      0.95       530
#
#     accuracy                           0.94      1031
#    macro avg       0.87      0.70      0.72      1031
# weighted avg       0.93      0.94      0.93      1031

# %%
cm = confusion_matrix(

    y_test,

    xgb_prediction

)


plt.figure(figsize=(6,5))


sns.heatmap(

    cm,

    annot=True,

    fmt="d",

    cmap="Blues",

    xticklabels=target_encoder.classes_,

    yticklabels=target_encoder.classes_

)


plt.xlabel(
"Predicted"
)


plt.ylabel(
"Actual"
)


plt.title(
"XGBoost Confusion Matrix"
)


plt.show()

# %%
probabilities = xgb_model.predict_proba(

    X_test

)

# %%
importance = pd.DataFrame({

    "Feature": features,

    "Importance": xgb_model.feature_importances_

})


importance = importance.sort_values(

    by="Importance",

    ascending=False

)


importance
# Out:
#             Feature  Importance
# 3       Crime_Count    0.891877
# 0     Location_Code    0.037111
# 4  Average_Severity    0.026445
# 1              Year    0.019829
# 2             Month    0.012819
# 5  Maximum_Severity    0.011918

# %%
joblib.dump(

    xgb_model,

    "/content/drive/MyDrive/SafeHood_ML/Models/xgboost_model3.pkl"

)


joblib.dump(

    target_encoder,

    "/content/drive/MyDrive/SafeHood_ML/Models/target_encoder3.pkl"

)
# Out:
# ['/content/drive/MyDrive/SafeHood_ML/Models/target_encoder3.pkl']
